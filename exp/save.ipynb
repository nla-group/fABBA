# %%
# !tar chvfz results.tar.gz *
# Out:
# _UCRArchive_2018/
# _UCRArchive_2018/README.md
# aggExp.ipynb
# clustering_com.ipynb
# count_rate_1norm.ipynb
# count_rate_2norm.ipynb
# count_rate_lexi.ipynb
# datasets/
# datasets/Images/
# datasets/Images/n02109961-Eskimo_dog/
# datasets/Images/n02109961-Eskimo_dog/n02109961_8977.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_5147.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_5772.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_5797.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_11634.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_16953.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_2964.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_3810.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_2369.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_2675.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_6143.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_20002.jpg
# datasets/Images/n02109961-Eskimo_dog/n02109961_7861.jpg
# ...
